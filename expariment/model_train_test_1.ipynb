# %% [markdown]
# # Train with Ultralytics

# %%
# !pip install roboflow ultralytics

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="fFAk12filLKHL2Wuk4ZR")
project = rf.workspace("project-szzpt").project("helmate-gxxio")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import os
import torch
from ultralytics import YOLO
from pathlib import Path

# %%
def data_path(dir_path):
        files_path = Path(dir_path)

        for file in os.listdir(files_path):
            if 'data/yaml' in file:
               print(Path(file))

# %%
dir_path =r'D:\CVProjects\Traffic-Saftey-Project\Artifacts\data_ingestion\FEATURE_STORE'
data_path(dir_path)

# %%
root_directory = os.path.dirname(os.path.abspath(dir_path))
print("Root Directory:", root_directory)
# Out:
# Root Directory: D:\CVProjects\Traffic-Saftey-Project\Artifacts\data_ingestion

# %%
# Dataset Paths
data_yaml = '/content/helmate-1/data.yaml'  # Ensure this file is correct
model_path = 'yolov5nu.pt'      # Pretrained model
output_dir = 'results/train'

# Set device
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load YOLOv12 model
model = YOLO(model_path)

# %%
results = model.train(
        data=data_yaml,
        epochs=3,
        batch=16,
        imgsz=640,
        project=output_dir
    )
# Out:
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
results = model.val()
# Out:
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/helmate-1/valid/labels.cache... 28 images, 0 backgrounds, 0 corrupt: 100%|██████████| 28/28 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:07<00:00,  3.60s/it]
#                    all         28        146     0.0031      0.193     0.0152    0.00547
#                 helmet         25         41          0          0          0          0
#          license_plate         23         55          0          0          0          0
#           motorcyclist         27         50    0.00929       0.58     0.0457     0.0164
# Speed: 1.7ms preprocess, 197.9ms inference, 0.0ms loss, 47.0ms postprocess per image
# Results saved to results/train/train42

# %%
results.results_dict['metrics/precision(B)']
# Out:
# np.float64(0.0030953143345074183)

# %%
model.metrics.results_dict.values()
# Out:
# dict_values([np.float64(0.0030953143345074183), np.float64(0.19333333333333333), np.float64(0.015231601639878396), np.float64(0.005472083688928374), np.float64(0.0064480354840233765)])

# %%
result=model('/content/helmate-1/test/images/IMG_5034-2_MOV-19_jpg.rf.814666842233f5e818477a35ead980ce.jpg')
# Out:
# image 1/1 /content/helmate-1/test/images/IMG_5034-2_MOV-19_jpg.rf.814666842233f5e818477a35ead980ce.jpg: 640x640 (no detections), 178.6ms
# Speed: 4.1ms preprocess, 178.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
model.save('model.pt')

# %%
infrance_model=YOLO('model.pt')

# %%
result = model.predict('/content/helmate-1/train/images/IMG_5030-2_MOV-16_jpg.rf.47d51295ee3dc594de2390ffcd8abc3f.jpg')
# Out:
# image 1/1 /content/helmate-1/train/images/IMG_5030-2_MOV-16_jpg.rf.47d51295ee3dc594de2390ffcd8abc3f.jpg: 640x640 (no detections), 296.4ms
# Speed: 16.0ms preprocess, 296.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
for r in result:
    print(r)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'helmet', 1: 'license_plate', 2: 'motorcyclist'}
# obb: None
# orig_img: array([[[ 36,  70,  59],
#         [ 58,  92,  81],
#         [ 84, 120, 108],
#         ...,
#         [114, 136, 202],
#         [115, 137, 203],
#         [116, 138, 204]],
#
#        [[ 36,  70,  59],
#         [ 57,  91,  80],
#         [ 73, 107,  96],
#         ...,
#         [114, 136, 202],
#         [115, 137, 203],
#         [116, 138, 204]],
#
#        [[ 43,  75,  64],
#         [ 60,  94,  83],
#         [ 59,  93,  82],
#         ...,
#         [114, 136, 202],
#         [116, 138, 204],
#         [116, 138, 204]],
#
#        ...,
#
#        [[165, 170, 169],
#         [165, 170, 169],
#         [163, 168, 167],
#         ...,
#         [179, 184, 183],
#         [178, 183, 182],
#         [180, 185, 184]],
#
#        [[167, 172, 171],
# ...

# %%
import cv2

# Predict with the model
img =  cv2.imread("/content/helmate-1/train/images/IMG_5030-2_MOV-16_jpg.rf.47d51295ee3dc594de2390ffcd8abc3f.jpg")  # predict on an image


# Run inference on 'bus.jpg' with arguments
model.predict(img, save=True, imgsz=320, conf=0.5)
# Out:
# 0: 320x320 2 persons, 1 bicycle, 70.5ms
# Speed: 1.9ms preprocess, 70.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to results/train/train44
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# Open the video file
video_path = "
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
